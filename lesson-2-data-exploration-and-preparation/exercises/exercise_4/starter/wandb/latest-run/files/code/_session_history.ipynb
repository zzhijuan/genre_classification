# %%
import pandas as pd
import seaborn as sns
from pandas_profiling import ProfileReport 
import wandb

# %%
artifact = run.use_artifact("genres_mod:latest")
# Out:
# '[]'

# %%
import pandas as pd
import seaborn as sns
from pandas_profiling import ProfileReport 
import wandb

# %%
run = wandb.init(project = "exercise_4", group = "experiment_1", job_type = 'profiling', save_code=True)
# Out:
# '[]'
# wandb version 0.19.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.4
# Run data is saved locally in <code>/Users/zhijuanzhang/Documents/UdacityCourse/MLOps_P2_Reproducible_Pipeline/Exercise/lesson-2-data-exploration-and-preparation/exercises/exercise_4/starter/wandb/run-20250115_192459-a2hgl4rg</code>
# Syncing run <strong><a href='https://wandb.ai/zzhijuan-university-of-houston/exercise_4/runs/a2hgl4rg' target="_blank">glad-plasma-6</a></strong> to <a href='https://wandb.ai/zzhijuan-university-of-houston/exercise_4' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/zzhijuan-university-of-houston/exercise_4' target="_blank">https://wandb.ai/zzhijuan-university-of-houston/exercise_4</a>
#  View run at <a href='https://wandb.ai/zzhijuan-university-of-houston/exercise_4/runs/a2hgl4rg' target="_blank">https://wandb.ai/zzhijuan-university-of-houston/exercise_4/runs/a2hgl4rg</a>

# %%
artifact = run.use_artifact("genres_mod:latest")
# Out:
# '[]'

# %%
df = pd.read_parquet(artifact.file())
# Out:
# '[]'

# %%
df
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.831   0.814    2    -7.364     1       0.4200      0.059800
# 1             0.719   0.493    8    -7.230     1       0.0794      0.401000
# 2             0.850   0.893    5       NaN     1       0.0623      0.013800
# 3             0.476   0.781    0    -4.710     1       0.1030      0.023700
# 4             0.798   0.624    2    -7.668     1       0.2930      0.217000
# ...             ...     ...  ...       ...   ...          ...           ...
# 42891         0.802   0.630    9    -9.348     0       0.4320      0.204000
# 42892         0.565   0.996   11       NaN     0       0.0682      0.000050
# 42893         0.514   0.955    0    -5.182     0       0.0402      0.000053
# 42894         0.749   0.639    1    -9.841     1       0.1940      0.080900
# 42895         0.645   0.980    0    -6.898     1       0.0445      0.000029
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.013400    0.0556   0.3890  156.985  audio_features
# 1              0.000000    0.1180   0.1240  115.080  audio_features
# 2              0.000004    0.3720   0.0391  218.050  audio_features
# 3              0.000000    0.1140   0.1750  186.948  audio_features
# 4              0.000000    0.1660   0.5910  147.988  audio_features
# ...                 ...       ...      ...      ...             ...
# 42891          0.000002    0.0649   0.8770  144.008  audio_features
# 42892          0.816000    0.9220   0.0658  145.000  audio_features
# 42893          0.889000    0.3380   0.1100  138.030  audio_features
# 42894          0.609000    0.3620   0.6490  153.003  audio_features
# 42895          0.843000    0.3180   0.2600  143.018  audio_features
#
#        duration_ms  time_signature            genre  \
# 0           124539               4        Dark Trap
# 1           224427               4        Dark Trap
# 2            98821               4        Dark Trap
# 3           123661               3        Dark Trap
# 4           123298               4        Dark Trap
# ...            ...             ...              ...
# 42891        66743               4  Underground Rap
# 42892       590875               4        psytrance
# 42893       221007               4           trance
# 42894       215202               4  Underground Rap
# 42895       443077               4        psytrance
#
#                                            song_name  \
# 0                                Mercury: Retrograde
# 1                                          Pathology
# 2                                           Symbiote
# 3      ProductOfDrugs (Prod. The Virus and Antidote)
# 4                                              Venom
# ...                                              ...
# 42891                                     Bang Bros!
# 42892                                           None
# 42893                                           None
# 42894                             Southern Hostility
# 42895                                           None
#
#                                            title
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
# ...                                          ...
# 42891                                       None
# 42892            PSYTRANCE BANGERS best new 2020
# 42893                      Top Trance Songs EVER
# 42894                                       None
# 42895  Psytrance: From Full on to Forrest Trance
#
# [42896 rows x 17 columns]

# %%
df.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5       NaN     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo            type  duration_ms  \
# 0          0.013400    0.0556   0.3890  156.985  audio_features       124539
# 1          0.000000    0.1180   0.1240  115.080  audio_features       224427
# 2          0.000004    0.3720   0.0391  218.050  audio_features        98821
# 3          0.000000    0.1140   0.1750  186.948  audio_features       123661
# 4          0.000000    0.1660   0.5910  147.988  audio_features       123298
#
#    time_signature      genre                                      song_name  \
# 0               4  Dark Trap                            Mercury: Retrograde
# 1               4  Dark Trap                                      Pathology
# 2               4  Dark Trap                                       Symbiote
# 3               3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4               4  Dark Trap                                          Venom
#
#   title
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None

# %%
from pandas_profiling import ProfileReport
# Out:
# '[{"varName": "df", "varType": "DataFrame", "varSize": "5833984", "varShape": "42896 rows x 17 cols", "varContent": "Columns: danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, duration_ms, time_sig ...", "isMatrix": true, "isWidget": false}]'

# %%
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
   profile.to_widgets()
# Out:
# '[{"varName": "df", "varType": "DataFrame", "varSize": "5833984", "varShape": "42896 rows x 17 cols", "varContent": "Columns: danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, duration_ms, time_sig ...", "isMatrix": true, "isWidget": false}]'

# %%
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)
profile.to_widgets()
# Out:
# '[{"varName": "df", "varType": "DataFrame", "varSize": "5833984", "varShape": "42896 rows x 17 cols", "varContent": "Columns: danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, duration_ms, time_sig ...", "isMatrix": true, "isWidget": false}]'
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
#                   acousticness  danceability  duration_ms    energy     genre  \
# acousticness          1.000000      0.211629    -0.399106 -0.534019  0.166200
# danceability          0.211629      1.000000    -0.109200 -0.371770  0.243026
# duration_ms          -0.399106     -0.109200     1.000000  0.310070  0.323398
# energy               -0.534019     -0.371770     0.310070  1.000000  0.227359
# genre                 0.166200      0.243026     0.323398  0.227359  1.000000
# instrumentalness     -0.507995     -0.141055     0.523679  0.384974  0.292591
# key                  -0.020709     -0.009176     0.065009  0.036936  0.077984
# liveness             -0.077151     -0.232332    -0.055896  0.212105  0.117581
# loudness             -0.179208     -0.265481    -0.050088  0.567597  0.226882
# mode                  0.025833      0.085748     0.080384  0.036371  0.169329
# speechiness           0.284715      0.254773    -0.294524 -0.098590  0.187263
# tempo                 0.090595     -0.239072    -0.125796  0.021245  0.420337
# time_signature        0.062614      0.074066     0.045262  0.059681  0.082731
# valence               0.190598      0.357979    -0.190379 -0.049910  0.183449
#
#                   instrumentalness       key  liveness  loudness      mode  \
# acousticness             -0.507995 -0.020709 -0.077151 -0.179208  0.025833
# danceability             -0.141055 -0.009176 -0.232332 -0.265481  0.085748
# duration_ms               0.523679  0.065009 -0.055896 -0.050088  0.080384
# energy                    0.384974  0.036936  0.212105  0.567597  0.036371
# genre                     0.292591  0.077984  0.117581  0.226882  0.169329
# instrumentalness          1.000000  0.066930 -0.052565 -0.141125  0.033482
# key                       0.066930  1.000000 -0.011254 -0.005785  0.413699
# liveness                 -0.052565 -0.011254  1.000000  0.182995  0.000000
# loudness                 -0.141125 -0.005785  0.182995  1.000000  0.025624
# mode                      0.033482  0.413699  0.000000  0.025624  1.000000
# speechiness              -0.429492 -0.015438  0.073209  0.074911  0.050667
# tempo                    -0.227692 -0.009628  0.087415  0.243802  0.049923
# time_signature            0.031546  0.014847  0.011393  0.046164  0.005614
# valence                  -0.355580  0.027192 -0.029927  0.082686  0.026303
#
#                   speechiness     tempo  time_signature   valence
# acousticness         0.284715  0.090595        0.062614  0.190598
# danceability         0.254773 -0.239072        0.074066  0.357979
# duration_ms         -0.294524 -0.125796        0.045262 -0.190379
# energy              -0.098590  0.021245        0.059681 -0.049910
# genre                0.187263  0.420337        0.082731  0.183449
# instrumentalness    -0.429492 -0.227692        0.031546 -0.355580
# key                 -0.015438 -0.009628        0.014847  0.027192
# liveness             0.073209  0.087415        0.011393 -0.029927
# loudness             0.074911  0.243802        0.046164  0.082686
# mode                 0.050667  0.049923        0.005614  0.026303
# speechiness          1.000000  0.185988        0.050816  0.271765
# tempo                0.185988  1.000000        0.065397  0.054536
# time_signature       0.050816  0.065397        1.000000  0.034131
# valence              0.271765  0.054536        0.034131  1.000000
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5       NaN     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
# 5         0.721   0.568    0   -11.295     1       0.4140        0.0452
# 6         0.718   0.668    8    -4.162     1       0.1370        0.0254
# 7         0.694   0.711    8       NaN     1       0.2210        0.0397
# 8         0.774   0.751    1    -2.445     1       0.1980        0.0614
# 9         0.893   0.907   11   -10.406     1       0.3670        0.1520
#
#    instrumentalness  liveness  valence    tempo            type  duration_ms  \
# 0          0.013400    0.0556   0.3890  156.985  audio_features       124539
# 1          0.000000    0.1180   0.1240  115.080  audio_features       224427
# 2          0.000004    0.3720   0.0391  218.050  audio_features        98821
# 3          0.000000    0.1140   0.1750  186.948  audio_features       123661
# 4          0.000000    0.1660   0.5910  147.988  audio_features       123298
# 5          0.212000    0.1280   0.1090  144.915  audio_features       112511
# 6          0.007800    0.1240   0.0380  130.826  audio_features        77584
# 7          0.000000    0.1120   0.2830  138.049  audio_features       127524
# 8          0.000000    0.0728   0.1890  219.960  audio_features       140326
# 9          0.031100    0.5580   0.3020  199.942  audio_features       121979
#
#    time_signature      genre                                      song_name  \
# 0               4  Dark Trap                            Mercury: Retrograde
# 1               4  Dark Trap                                      Pathology
# 2               4  Dark Trap                                       Symbiote
# 3               3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4               4  Dark Trap                                          Venom
# 5               4  Dark Trap                                        Gatteka
# 6               4  Dark Trap                             kamikaze (+ pulse)
# 7               3  Dark Trap            T.R.U. (Totally Rotten Underground)
# 8               4  Dark Trap                   I Put My Dick in Your Mental
# 9               4  Dark Trap                                      Andromeda
#
#   title
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 42886         0.875   0.753    8    -6.899     0       0.0901      0.040500
# 42887         0.589   0.783    6   -11.170     1       0.0413      0.000421
# 42888         0.623   0.845    8    -9.082     1       0.0508      0.016000
# 42889         0.674   0.990    5       NaN     1       0.2840      0.312000
# 42890         0.653   0.944    2       NaN     1       0.0917      0.001630
# 42891         0.802   0.630    9    -9.348     0       0.4320      0.204000
# 42892         0.565   0.996   11       NaN     0       0.0682      0.000050
# 42893         0.514   0.955    0    -5.182     0       0.0402      0.000053
# 42894         0.749   0.639    1    -9.841     1       0.1940      0.080900
# 42895         0.645   0.980    0    -6.898     1       0.0445      0.000029
#
#        instrumentalness  liveness  valence    tempo            type  \
# 42886          0.000099    0.1680   0.7350  112.002  audio_features
# 42887          0.916000    0.0839   0.0345  123.995  audio_features
# 42888          0.864000    0.0862   0.3690  134.978  audio_features
# 42889          0.000016    0.6270   0.5090  173.948  audio_features
# 42890          0.473000    0.3520   0.0754  139.970  audio_features
# 42891          0.000002    0.0649   0.8770  144.008  audio_features
# 42892          0.816000    0.9220   0.0658  145.000  audio_features
# 42893          0.889000    0.3380   0.1100  138.030  audio_features
# 42894          0.609000    0.3620   0.6490  153.003  audio_features
# 42895          0.843000    0.3180   0.2600  143.018  audio_features
#
#        duration_ms  time_signature            genre           song_name  \
# 42886       210187               4       Trap Metal         Smoke Break
# 42887       410323               4           techno                None
# 42888       546707               4           trance                None
# 42889       182069               4              dnb                None
# 42890       221000               4           trance                None
# 42891        66743               4  Underground Rap          Bang Bros!
# 42892       590875               4        psytrance                None
# 42893       221007               4           trance                None
# 42894       215202               4  Underground Rap  Southern Hostility
# 42895       443077               4        psytrance                None
#
#                                            title
# 42886                                       None
# 42887                           Dark Techno Rave
# 42888                      Top Trance Songs EVER
# 42889              UKF Drum & Bass - All Uploads
# 42890    TRANNCE 2020 Best Trance Music Official
# 42891                                       None
# 42892            PSYTRANCE BANGERS best new 2020
# 42893                      Top Trance Songs EVER
# 42894                                       None
# 42895  Psytrance: From Full on to Forrest Trance
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 422         0.631   0.623    8    -6.969     1       0.2650      0.463000
# 60          0.389   0.768    1    -4.765     1       0.2560      0.038000
# 98          0.431   0.961    2    -6.598     0       0.0603      0.000246
# 146         0.473   0.735   11    -6.131     0       0.0498      0.010600
# 150         0.476   0.407    4    -9.239     0       0.0368      0.247000
# 182         0.495   0.891    1    -5.599     0       0.0504      0.001870
# 219         0.513   0.855    8    -3.664     1       0.0375      0.029300
# 285         0.548   0.554    9    -6.408     1       0.0587      0.283000
# 301         0.554   0.978    4       NaN     1       0.1310      0.111000
# 419         0.629   0.696    1    -5.572     0       0.3480      0.019500
#
#      instrumentalness  liveness  valence    tempo            type  \
# 422          0.000002    0.1510   0.7650  160.460  audio_features
# 60           0.000000    0.1190   0.3340   90.146  audio_features
# 98           0.207000    0.3680   0.1630  138.001  audio_features
# 146          0.000000    0.2660   0.6500  154.546  audio_features
# 150          0.000000    0.1440   0.2260  178.258  audio_features
# 182          0.112000    0.3220   0.2240  149.982  audio_features
# 219          0.933000    0.3160   0.0367  173.996  audio_features
# 285          0.000000    0.0708   0.3820  159.836  audio_features
# 301          0.000000    0.0731   0.5940  135.095  audio_features
# 419          0.000000    0.0554   0.6230  186.068  audio_features
#
#      duration_ms  time_signature      genre                song_name  \
# 422       227893               4     Hiphop          Everything I Am
# 60        183567               4        Rap  WRONG (feat. Lil Mosey)
# 98        235187               4     trance                      NaN
# 146       179453               4        Emo    You're So Last Summer
# 150       242467               4        RnB   Officially Missing You
# 182       142400               4  hardstyle                      NaN
# 219       364149               4        dnb                      NaN
# 285       207507               4        RnB                Stickwitu
# 301       162600               4        Emo                    Faint
# 419       207627               4     Hiphop              Gold Digger
#
#                                        title  # duplicates
# 422                                      NaN             4
# 60                                       NaN             3
# 98   TRANNCE 2020 Best Trance Music Official             3
# 146                                      NaN             3
# 150                                      NaN             3
# 182   Euphoric Hardstyle & Melodic Hardstyle             3
# 219                       Liquid Drum & Bass             3
# 285                                      NaN             3
# 301                                      NaN             3
# 419                                      NaN             3
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
df = df.drop_duplicates().reset_index(drop=True)
# Out:
# '[{"varName": "df", "varType": "DataFrame", "varSize": "5833984", "varShape": "42896 rows x 17 cols", "varContent": "Columns: danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, duration_ms, time_sig ...", "isMatrix": true, "isWidget": false}]'

# %%
df['title'].fillna(value='', inplace=True)
df['song_name'].fillna(value='', inplace=True)
df['text_feature'] = df['title'] + ' ' + df['song_name']
# Out:
# '[{"varName": "df", "varType": "DataFrame", "varSize": "5708728", "varShape": "41975 rows x 17 cols", "varContent": "Columns: danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, duration_ms, time_sig ...", "isMatrix": true, "isWidget": false}]'

# %%
run.finish()
# Out:
# '[{"varName": "df", "varType": "DataFrame", "varSize": "6044528", "varShape": "41975 rows x 18 cols", "varContent": "Columns: danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, duration_ms, time_sig ...", "isMatrix": true, "isWidget": false}]'
